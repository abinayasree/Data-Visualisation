# %% [markdown]
# <a href="https://colab.research.google.com/github/abinayasree/Data-Visualisation/blob/main/Data_Visualisation_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# VISUALISATION USING SEABORN

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load sample dataset
tips = sns.load_dataset("tips")

# Create scatter plot
sns.scatterplot(x="total_bill", y="tip", data=tips)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Movies = ['Minecraft','Call Of Duty','FIFA','Valorant','Resident Evil']
Percentage = [23,30,21,19,7]

# %%
plt.pie(Percentage, labels=Movies)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f50840e4cd0>,
#   <matplotlib.patches.Wedge at 0x7f50840e4be0>,
#   <matplotlib.patches.Wedge at 0x7f50840f74c0>,
#   <matplotlib.patches.Wedge at 0x7f50840f7940>,
#   <matplotlib.patches.Wedge at 0x7f50840f7dc0>],
#  [Text(0.8251221670583667, 0.7274430626715089, 'Minecraft'),
#   Text(-0.8018655381043114, 0.7530017654698317, 'Call Of Duty'),
#   Text(-0.7274429854179931, -0.825122235166498, 'FIFA'),
#   Text(0.5599456069679137, -0.9468162003458405, 'Valorant'),
#   Text(1.073508449141181, -0.23995751628673068, 'Resident Evil')])

# %%
plt.bar(Movies, Percentage)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# SIN WAVE PLOT

# %%
import numpy as np

# %%
time = np.arange(0, 10, 0.05)

# %%
amplitude = np.sin(time)
plt.plot(time, amplitude)

# %%
data1 = np.linspace(-5, 5, 100)
data2 = np.linspace(-5, 5, 100)

# %%
[x, y] = np.meshgrid(data1, data2)

# %%
z = x**2 + y**2

# %%
figure, ax = plt.subplots(1,1)
ax.contourf(x, y, z)
ax.set_title('Contour Plot(Filled)')
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.show()

# %%
data1 = np.random.normal(100, 10, 100)
data2 = np.random.normal(80, 30, 100)
data3 = np.random.normal(60, 50, 100)

# %%
data = [data1, data2, data3]

# %%
figure = plt.figure(figsize=(8, 5))
ax = figure.add_axes([0, 0, 1, 1])
ax.boxplot(data)
plt.show()

# %% [markdown]
# SCATTER PLOT

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt


# Creating dataset
z = np.random.randint(100, size =(50))
x = np.random.randint(80, size =(50))
y = np.random.randint(60, size =(50))

# Creating figure
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")

# Creating plot
ax.scatter3D(x, y, z, color = "green")
plt.title("simple 3D scatter plot")

# show plot
plt.show()

# %% [markdown]
# WORKING WITH IMAGES

# %%
import matplotlib.image as mpimg

# %%
img = mpimg.imread('/content/CHESS.png')

# %%
imgplot = plt.imshow(img)

# %%
plt.imsave("upside.png", img, origin='lower')
saved = mpimg.imread('upside.png')
plt.imshow(saved)

# %%
x = np.outer(np.linspace(-5,5,25), np.ones(25))
y = x.copy().T
z = (np.sin(x**2) + np.cos(y**2))

# %%
figure = plt.figure(figsize = (10, 7))
ax = plt.axes(projection = '3d')
ax.plot_surface(x, y, z)
plt.show()
